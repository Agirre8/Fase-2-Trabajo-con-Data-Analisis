# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data= pd.read_csv('imdb_top_1000.csv')

# %%
data
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
# Conteo de valores perdidos/faltantes  
data.isna().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
data['Certificate'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999     True
# Name: Certificate, Length: 1000, dtype: bool

# %%
data['Certificate'].isna().sum()
# Out:
# 101

# %%
data.drop(data.dropna().index)
# Out:
#                                            Poster_Link  \
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 30   https://m.media-amazon.com/images/M/MV5BYjBmYT...
# 32   https://m.media-amazon.com/images/M/MV5BZjc4ND...
# 46   https://m.media-amazon.com/images/M/MV5BZmY2Nj...
# ..                                                 ...
# 993  https://m.media-amazon.com/images/M/MV5BYTE4YW...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 18                 Hamilton          2020       PG-13  160 min
# 20          Soorarai Pottru          2020           U  153 min
# 30                  Seppuku          1962         NaN  133 min
# ...

# %%
data_filt=data.dropna().reset_index(drop=True)
data_filt
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 709  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 710  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 711  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 712  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 713  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
data_filt.isna().sum()
#aqui comprobamos que el nuevo dataset no tiene ningun valor nulo!!
# Out:
# Poster_Link      0
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %%
data_filt.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count   714.000000  714.000000  7.140000e+02
# mean      7.937115   77.158263  3.561348e+05
# std       0.293278   12.401144  3.539011e+05
# min       7.600000   28.000000  2.522900e+04
# 25%       7.700000   70.000000  9.600975e+04
# 50%       7.900000   78.000000  2.366025e+05
# 75%       8.100000   86.000000  5.077922e+05
# max       9.300000  100.000000  2.343110e+06

# %%
#consultamos el tipo de datos
data_filt.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
#eliminamos la columna de imagen ya que no nos va a resultar util
columnas_drop=["Poster_Link","Gross","Overview","Certificate","Star2","Star3","Star4","Meta_score"]

# %%
data_filt_2= data_filt.drop(columns=columnas_drop)
data_filt_2
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 709              Giù la testa          1971  157 min
# 710            Kelly's Heroes          1970  144 min
# 711           The Jungle Book          1967   78 min
# 712        A Hard Day's Night          1964   87 min
# 713     From Here to Eternity          1953  118 min
#
#                             Genre  IMDB_Rating              Director  \
# 0                           Drama          9.3        Frank Darabont
# 1                    Crime, Drama          9.2  Francis Ford Coppola
# 2            Action, Crime, Drama          9.0     Christopher Nolan
# ...

# %%
data_filt_2.dtypes.value_counts()
# Out:
# object     6
# float64    1
# int64      1
# dtype: int64

# %%
data_filt_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   Released_Year  714 non-null    object
#  2   Runtime        714 non-null    object
#  3   Genre          714 non-null    object
#  4   IMDB_Rating    714 non-null    float64
#  5   Director       714 non-null    object
#  6   Star1          714 non-null    object
#  7   No_of_Votes    714 non-null    int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 44.8+ KB

# %%
data_filt_2['Released_Year'] = pd.to_numeric(data_filt_2['Released_Year'], errors='coerce')
data_filt_2['No_of_Votes'] = pd.to_numeric(data_filt_2['No_of_Votes'], errors='coerce')

# %%
data_filt_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   Released_Year  713 non-null    float64
#  2   Runtime        714 non-null    object
#  3   Genre          714 non-null    object
#  4   IMDB_Rating    714 non-null    float64
#  5   Director       714 non-null    object
#  6   Star1          714 non-null    object
#  7   No_of_Votes    714 non-null    int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 44.8+ KB

# %%
data_filt_2['Runtime'] = data_filt_2['Runtime'].str.replace(' min', '')
data_filt_2['Runtime'] = pd.to_numeric(data_filt_2['Runtime'], errors='coerce')

# %%
data_filt_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   Released_Year  713 non-null    float64
#  2   Runtime        714 non-null    int64
#  3   Genre          714 non-null    object
#  4   IMDB_Rating    714 non-null    float64
#  5   Director       714 non-null    object
#  6   Star1          714 non-null    object
#  7   No_of_Votes    714 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 44.8+ KB

# %%
data_filt_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   Released_Year  713 non-null    float64
#  2   Runtime        714 non-null    int64
#  3   Genre          714 non-null    object
#  4   IMDB_Rating    714 non-null    float64
#  5   Director       714 non-null    object
#  6   Star1          714 non-null    object
#  7   No_of_Votes    714 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 44.8+ KB

# %%
data_filt_2.dtypes
# Out:
# Series_Title      object
# Released_Year    float64
# Runtime            int64
# Genre             object
# IMDB_Rating      float64
# Director          object
# Star1             object
# No_of_Votes        int64
# dtype: object

# %%
print(data_filt_2["Genre"])
# Out:
# 0                             Drama
# 1                      Crime, Drama
# 2              Action, Crime, Drama
# 3                      Crime, Drama
# 4                      Crime, Drama
#                    ...
# 709             Drama, War, Western
# 710          Adventure, Comedy, War
# 711    Animation, Adventure, Family
# 712          Comedy, Music, Musical
# 713             Drama, Romance, War
# Name: Genre, Length: 714, dtype: object

# %%
encoder = LabelEncoder()
encoded_data = encoder.fit_transform(data_filt_2['Series_Title'])
data_filt_2['Series_numerico'] = encoder.fit_transform(data_filt_2['Series_Title'])

# %%
data_filt_2.dtypes
# Out:
# Series_Title        object
# Released_Year      float64
# Runtime              int64
# Genre               object
# IMDB_Rating        float64
# Director            object
# Star1               object
# No_of_Votes          int64
# Series_numerico      int64
# dtype: object

# %%
print(data_filt_2["Series_numerico"])
# Out:
# 0      630
# 1      562
# 2      547
# 3      563
# 4        1
#       ...
# 709    218
# 710    297
# 711    586
# 712     17
# 713    208
# Name: Series_numerico, Length: 714, dtype: int64

# %%
# Buscamos el valor numérico correspondiente al título "Pulp Fiction"
valor_numerico = data_filt_2.loc[data_filt_2['Series_Title'] == 'Pulp Fiction', 'Series_numerico'].iloc[0]

# Mostramos el valor numérico
print(valor_numerico)

# Buscamos el título correspondiente al valor numérico 446
titulo = data_filt_2.loc[data_filt_2['Series_numerico'] == 446, 'Series_Title'].iloc[0]

# Mostramos el título
print(titulo)
# Out:
# 446
# Pulp Fiction

# %%
#asignamos valores numericos a Director
encoderD = LabelEncoder()
encoded_dataD = encoderD.fit_transform(data_filt_2['Director'])
data_filt_2['Director_numerico'] = encoderD.fit_transform(data_filt_2['Director'])

# %%
data_filt_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Series_Title       714 non-null    object
#  1   Released_Year      713 non-null    float64
#  2   Runtime            714 non-null    int64
#  3   Genre              714 non-null    object
#  4   IMDB_Rating        714 non-null    float64
#  5   Director           714 non-null    object
#  6   Star1              714 non-null    object
#  7   No_of_Votes        714 non-null    int64
#  8   Series_numerico    714 non-null    int64
#  9   Director_numerico  714 non-null    int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 55.9+ KB

# %%
# Definimos el nombre del director que queremos buscar
nombre_director = "Woody Allen"

# Obtenemos el valor numérico correspondiente al nombre del director
valor_numerico_director = data_filt_2.loc[data_filt_2['Director'] == nombre_director, 'Director_numerico'].iloc[0]

# Filtramos el DataFrame para obtener las películas dirigidas por el director
peliculas_director = data_filt_2.loc[data_filt_2['Director_numerico'] == valor_numerico_director]

# Mostramos las películas dirigidas por el director
print(peliculas_director)
# Out:
#                  Series_Title  Released_Year  Runtime  \
# 277                Annie Hall         1977.0       93
# 356   Crimes and Misdemeanors         1989.0      104
# 358    Hannah and Her Sisters         1986.0      107
# 363                 Manhattan         1979.0       96
# 504         Midnight in Paris         2011.0       96
# 585  The Purple Rose of Cairo         1985.0       82
# 651               Match Point         2005.0      124
#
#                         Genre  IMDB_Rating     Director               Star1  \
# 277           Comedy, Romance          8.0  Woody Allen         Woody Allen
# 356             Comedy, Drama          7.9  Woody Allen       Martin Landau
# 358             Comedy, Drama          7.9  Woody Allen          Mia Farrow
# 363    Comedy, Drama, Romance          7.9  Woody Allen         Woody Allen
# 504  Comedy, Fantasy, Romance          7.7  Woody Allen         Owen Wilson
# ...

# %%
#hacemos lo mismo con la estrella
encoderS= LabelEncoder()
encoded_dataS = encoderS.fit_transform(data_filt_2['Star1'])
data_filt_2['Star1_numerico'] = encoder.fit_transform(data_filt_2['Star1'])

# %%
nombre_star="Brad Pitt"
valor_numerico_star = data_filt_2.loc[data_filt_2['Star1'] == nombre_star, 'Star1_numerico'].iloc[0]

# Filtramos el DataFrame para obtener las películas de brad Pitt
peliculas_star = data_filt_2.loc[data_filt_2['Star1_numerico'] == valor_numerico_star]

# Mostramos las películas protagonizadas por Brad Pitt
print(peliculas_star)
# Out:
#                             Series_Title  Released_Year  Runtime  \
# 9                             Fight Club         1999.0      139
# 72                  Inglourious Basterds         2009.0      153
# 421  The Curious Case of Benjamin Button         2008.0      166
# 635                            Moneyball         2011.0      133
#
#                        Genre  IMDB_Rating           Director      Star1  \
# 9                      Drama          8.8      David Fincher  Brad Pitt
# 72     Adventure, Drama, War          8.3  Quentin Tarantino  Brad Pitt
# 421  Drama, Fantasy, Romance          7.8      David Fincher  Brad Pitt
# 635  Biography, Drama, Sport          7.6     Bennett Miller  Brad Pitt
#
#      No_of_Votes  Series_numerico  Director_numerico  Star1_numerico
# 9        1854740              199                 71              50
# 72       1267869              274                292              50
# 421       589160              546                 71              50
# ...

# %%
data_filt_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Series_Title       714 non-null    object
#  1   Released_Year      713 non-null    float64
#  2   Runtime            714 non-null    int64
#  3   Genre              714 non-null    object
#  4   IMDB_Rating        714 non-null    float64
#  5   Director           714 non-null    object
#  6   Star1              714 non-null    object
#  7   No_of_Votes        714 non-null    int64
#  8   Series_numerico    714 non-null    int64
#  9   Director_numerico  714 non-null    int64
#  10  Star1_numerico     714 non-null    int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 61.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# Crear una instancia de LabelEncoder
encoder = LabelEncoder()

# Obtener una lista de todas las etiquetas de género en el DataFrame
generos = [genero.strip() for etiquetas in data_filt_2['Genre'] for genero in etiquetas.split(',')]

# Asignar un número entero a cada etiqueta de género
encoder.fit(generos)
numeros_generos = {genero: encoder.transform([genero])[0] + 1 for genero in generos}

# Crear una lista de listas con los números enteros de género para cada película
etiquetas_numericas = [list(map(lambda x: numeros_generos[x.strip()], etiquetas.split(','))) for etiquetas in data_filt_2['Genre']]

# Agregar una nueva columna al DataFrame con las etiquetas numéricas
data_filt_2['GenerosNumericos'] = etiquetas_numericas

# Imprimir el resultado
print(etiquetas_numericas)
# Out:
# [[7], [6, 7], [1, 6, 7], [6, 7], [6, 7], [1, 2, 7], [6, 7], [4, 7, 11], [1, 2, 17], [7], [1, 2, 7], [7, 16], [21], [1, 2, 7], [1, 17], [4, 6, 7], [1, 2, 9], [7], [5, 7, 19], [2, 7, 17], [6, 7], [3, 2, 8], [7, 20], [6, 7, 9], [5, 7, 16], [6, 7, 15], [6, 7, 19], [1, 2, 9], [1, 2, 7], [6, 7, 19], [7, 13], [4, 5, 7], [7, 15, 17], [6, 7, 19], [4, 7, 13], [1, 2, 7], [7], [6, 15, 19], [1, 6, 7], [3, 2, 7], [1, 17], [7, 16], [2, 5, 17], [21], [12, 15, 19], [7, 16, 20], [5, 7, 8], [5, 7, 16], [7], [3, 7, 9], [3, 1, 2], [1, 2, 7], [1, 2, 17], [3, 2, 8], [7, 21], [1, 2], [5, 7], [3, 2, 8], [7, 15, 19], [1, 7, 15], [15, 19], [3, 1, 2], [1, 2], [7, 12], [7, 15, 20], [12, 17], [5], [15, 19], [7, 19, 20], [7], [7], [7, 15, 20], [2, 7, 20], [7, 16, 17], [5, 16], [5, 6], [7], [7], [7, 16], [7, 8, 18], [3, 2, 5], [4, 7, 11], [6, 7, 19], [7, 20], [1, 2, 17], [4, 7, 11], [6, 7], [1, 2, 9], [2, 7, 19], [6, 7], [5, 6, 7], [6, 7, 17], [2, 17], [21], [2, 4, 7], [5, 7, 16], [2, 15, 19], [15, 16, 19], [5, 14,
# ...

# %%
data_filt_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Series_Title       714 non-null    object
#  1   Released_Year      713 non-null    float64
#  2   Runtime            714 non-null    int64
#  3   Genre              714 non-null    object
#  4   IMDB_Rating        714 non-null    float64
#  5   Director           714 non-null    object
#  6   Star1              714 non-null    object
#  7   No_of_Votes        714 non-null    int64
#  8   Series_numerico    714 non-null    int64
#  9   Director_numerico  714 non-null    int64
#  10  Star1_numerico     714 non-null    int64
#  11  GenerosNumericos   714 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 67.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# Crear una instancia de LabelEncoder
encoder = LabelEncoder()

# Obtener una lista de todas las etiquetas de género en el DataFrame
generos = [genero.strip() for etiquetas in data['Genre'] for genero in etiquetas.split(',')]

# Asignar un número entero a cada etiqueta de género
encoder.fit(generos)
numeros_generos = {genero: encoder.transform([genero])[0] + 1 for genero in generos}

# Crear una lista de listas con los números enteros de género para cada película
etiquetas_numericas = [list(map(lambda x: numeros_generos[x.strip()], etiquetas.split(','))) for etiquetas in data['Genre']]

# Agregar una nueva columna al DataFrame con las etiquetas numéricas
data['GenerosNumericos'] = etiquetas_numericas

# Imprimir el resultado
print(etiquetas_numericas)
# Out:
# [[7], [6, 7], [1, 6, 7], [6, 7], [6, 7], [1, 2, 7], [6, 7], [4, 7, 11], [1, 2, 17], [7], [1, 2, 7], [7, 16], [21], [1, 2, 7], [1, 17], [4, 6, 7], [1, 2, 9], [7], [4, 7, 11], [5, 7, 19], [7], [2, 7, 17], [6, 7], [3, 2, 8], [7, 20], [6, 7, 9], [5, 7, 16], [6, 7, 15], [6, 7, 19], [1, 2, 9], [1, 7, 15], [1, 2, 7], [7, 8, 9], [6, 7, 19], [7, 13], [4, 5, 7], [7, 15, 17], [6, 7, 19], [4, 7, 13], [1, 2, 7], [7], [6, 15, 19], [1, 6, 7], [3, 2, 7], [1, 17], [7, 16], [3, 7, 20], [2, 5, 17], [21], [12, 15, 19], [7, 16, 20], [5, 7, 8], [5, 7, 16], [7], [4, 7, 11], [1, 6, 7], [3, 7, 9], [1, 4, 7], [3, 1, 2], [1, 2, 7], [1, 2, 17], [3, 2, 8], [7, 21], [1, 2], [5, 7], [7, 8], [3, 2, 8], [7, 15, 19], [1, 7, 15], [15, 19], [3, 1, 2], [6, 7], [1, 2], [7, 12], [7, 15, 20], [12, 17], [7, 14], [6, 7, 15], [5], [6, 7, 15], [7, 20], [15, 19], [7, 10], [5, 7, 20], [7, 19, 20], [7, 9, 12], [6, 7, 13], [6, 7, 19], [7], [7], [7, 15, 20], [7], [7, 8], [2, 7, 20], [7, 16, 17], [5, 16], [5, 6], [7], [7], [7, 16], 
# ...

# %%
data_filt_2['GenerosNumericos'] = pd.to_numeric(data_filt_2['GenerosNumericos'], errors='coerce')

# %%
data_filt_2.info
# Out:
# <bound method DataFrame.info of                  Series_Title  Released_Year  Runtime  \
# 0    The Shawshank Redemption         1994.0      142
# 1               The Godfather         1972.0      175
# 2             The Dark Knight         2008.0      152
# 3      The Godfather: Part II         1974.0      202
# 4                12 Angry Men         1957.0       96
# ..                        ...            ...      ...
# 709              Giù la testa         1971.0      157
# 710            Kelly's Heroes         1970.0      144
# 711           The Jungle Book         1967.0       78
# 712        A Hard Day's Night         1964.0       87
# 713     From Here to Eternity         1953.0      118
#
#                             Genre  IMDB_Rating              Director  \
# 0                           Drama          9.3        Frank Darabont
# 1                    Crime, Drama          9.2  Francis Ford Coppola
# 2            Action, Crime, Drama          9.0     Christopher Nolan
# ...

# %%
data_filt_2.dtypes
# Out:
# Series_Title          object
# Released_Year        float64
# Runtime                int64
# Genre                 object
# IMDB_Rating          float64
# Director              object
# Star1                 object
# No_of_Votes            int64
# Series_numerico        int64
# Director_numerico      int64
# Star1_numerico         int64
# GenerosNumericos     float64
# dtype: object

# %%
data_filt_3 = data_filt_2.copy()

# %%
columnas_drop= ["Series_Title",
                "Genre",
                "Director",
                "Star1", "GenerosNumericos", "Series_numerico", "Director_numerico", "Star1_numerico"]

data_filt_3 = data_filt_3.drop(columns=columnas_drop)

# %%
data_filt_3.dtypes
# Out:
# Released_Year    float64
# Runtime            int64
# IMDB_Rating      float64
# No_of_Votes        int64
# dtype: object

# %%
# Generar la lista de features y la variable target
target = 'IMDB_Rating'
features = [x for x in data_filt_3.columns if x!=target]

print(target)
print(features)
# Out:
# IMDB_Rating
# ['Released_Year', 'Runtime', 'No_of_Votes']

# %%
data_filt_3[target]
# Out:
# 0      9.3
# 1      9.2
# 2      9.0
# 3      9.0
# 4      9.0
#       ...
# 709    7.6
# 710    7.6
# 711    7.6
# 712    7.6
# 713    7.6
# Name: IMDB_Rating, Length: 714, dtype: float64

# %%
data_filt_3 = data_filt_3.dropna()

# %%
data_filt_3.isna().sum()
# Out:
# Released_Year    0
# Runtime          0
# IMDB_Rating      0
# No_of_Votes      0
# dtype: int64

# %%
# Importar el algoritmo de árboles de decisión
from sklearn.tree import DecisionTreeRegressor

# Asignar el algortimo e indicar la profundidad máxima del árbol (con un número rotandamente grande para sobreajustar)
arbol_importancia = DecisionTreeRegressor(max_depth=len(features)+10, random_state=100)

# Entrenar un árbol con todo el conjunto de datos
arbol_importancia.fit(X=data_filt_3[features], y=data_filt_3[target])
# Out:
# DecisionTreeRegressor(max_depth=13, random_state=100)

# %%
y_pred_arbol = arbol_importancia.predict(X=data_filt_3[features])

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Métricas para evaluar la calidad del modelo
print('Mean Absolute Error:', mean_absolute_error(data_filt_3[target], y_pred_arbol))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(data_filt_3[target], y_pred_arbol)*100)
print('Mean Squared Error:', mean_squared_error(data_filt_3[target], y_pred_arbol))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(data_filt_3[target], y_pred_arbol)))
print('R^2 coefficient of determination:', r2_score(data_filt_3[target], y_pred_arbol))
# Out:
# Mean Absolute Error: 0.04818047899582092
# Mean Absolute Percentage Error: 0.6150479070982736
# Mean Squared Error: 0.008487351570524415
# Root Mean Squared Error: 0.09212682329552244
# R^2 coefficient of determination: 0.9011400160992139

# %%
#Te da los porcentajes de importancia, siemrpe va a sumar 1

arbol_importancia.feature_importances_
# Out:
# array([0.21052154, 0.11536138, 0.67411709])
